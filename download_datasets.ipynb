# %%
import os

# %%
from modelarts.session import Session
session = Session()

# %%
# !ls
# Out:
# DIV2K			 investigate.ipynb   rdn-results
# download_datasets.ipynb  LICENSE	     README.md
# EDSR-PyTorch-master	 RDN-pytorch-master  requirements.txt

# %%
bucket_path="cv-course-public/coding 3/datasets/SR_testing_datasets.zip" 
session.download_data(bucket_path=bucket_path, path="./SR_testing_datasets.zip")

# !unzip SR_testing_datasets.zip
# Out:
# Successfully download file cv-course-public/coding 3/datasets/SR_testing_datasets.zip from OBS to local ./SR_testing_datasets.zip
# Archive:  SR_testing_datasets.zip
#    creating: BSDS100/
#   inflating: BSDS100/86000.png
#   inflating: BSDS100/19021.png
#   inflating: BSDS100/361010.png
#   inflating: BSDS100/102061.png
#   inflating: BSDS100/33039.png
#   inflating: BSDS100/157055.png
#   inflating: BSDS100/208001.png
#   inflating: BSDS100/167062.png
#   inflating: BSDS100/145086.png
#   inflating: BSDS100/69015.png
#   inflating: BSDS100/58060.png
#   inflating: BSDS100/300091.png
#   inflating: BSDS100/220075.png
#   inflating: BSDS100/108005.png
#   inflating: BSDS100/41033.png
#   inflating: BSDS100/302008.png
#   inflating: BSDS100/97033.png
#   inflating: BSDS100/296007.png
#   inflating: BSDS100/62096.png
#   inflating: BSDS100/175032.png
#   inflating: BSDS100/167083.png
#   inflating: BSDS100/260058.png
#   inflating: BSDS100/86068.png
#   inflating: BSDS100/148089.png
# ...

# %%
# !mkdir DIV2K
# Out:
# mkdir: cannot create directory ‘DIV2K’: File exists

# %%
bucket_path="cv-course-public/coding 3/datasets/high resolution images/DIV2K_train_HR.zip" 
session.download_data(bucket_path=bucket_path, path="./DIV2K/DIV2K_train_HR.zip")

bucket_path="cv-course-public/coding 3/datasets/high resolution images/DIV2K_valid_HR.zip" 
session.download_data(bucket_path=bucket_path, path="./DIV2K/DIV2K_valid_HR.zip")

os.chdir("DIV2K")

# !unzip DIV2K_train_HR.zip
# !unzip DIV2K_valid_HR.zip

os.chdir("../")
# Out:
# Successfully download file cv-course-public/coding 3/datasets/high resolution images/DIV2K_train_HR.zip from OBS to local ./DIV2K/DIV2K_train_HR.zip
# Successfully download file cv-course-public/coding 3/datasets/high resolution images/DIV2K_valid_HR.zip from OBS to local ./DIV2K/DIV2K_valid_HR.zip
# Archive:  DIV2K_train_HR.zip
#    creating: DIV2K_train_HR/
#   inflating: DIV2K_train_HR/0103.png
#   inflating: DIV2K_train_HR/0413.png
#   inflating: DIV2K_train_HR/0031.png
#   inflating: DIV2K_train_HR/0660.png
#   inflating: DIV2K_train_HR/0126.png
#   inflating: DIV2K_train_HR/0793.png
#   inflating: DIV2K_train_HR/0764.png
#   inflating: DIV2K_train_HR/0550.png
#   inflating: DIV2K_train_HR/0437.png
#   inflating: DIV2K_train_HR/0374.png
#   inflating: DIV2K_train_HR/0755.png
#   inflating: DIV2K_train_HR/0614.png
#   inflating: DIV2K_train_HR/0646.png
#   inflating: DIV2K_train_HR/0371.png
#   inflating: DIV2K_train_HR/0312.png
#   inflating: DIV2K_train_HR/0108.png
# ...

# %%
# !ls
# Out:
# DIV2K			 investigate.ipynb   rdn-results
# download_datasets.ipynb  LICENSE	     README.md
# EDSR-PyTorch-master	 RDN-pytorch-master  requirements.txt

# %%
os.chdir("/home/ma-user/work/resnet-for-sr/")
# !ls
# Out:
# DIV2K			 EDSR-PyTorch-master.zip  RDN-pytorch-master.zip
# download_datasets.ipynb  investigate.ipynb	  rdn-results
# EDSR-PyTorch-master	 RDN-pytorch-master	  requirements.txt

# %%
bucket_path="cv-course-public/coding 3/codebase/RDN-pytorch-master.zip"
session.download_data(bucket_path=bucket_path, path="./RDN-pytorch-master.zip")

bucket_path="cv-course-public/coding 3/codebase/EDSR-PyTorch-master.zip"
session.download_data(bucket_path=bucket_path, path="./EDSR-PyTorch-master.zip")

# %%
# !ls
# Out:
# DIV2K			 investigate.ipynb   rdn-results
# download_datasets.ipynb  LICENSE	     README.md
# EDSR-PyTorch-master	 RDN-pytorch-master  requirements.txt

# %%
session.upload_data(bucket_path="/mipt-course/tendai/rdn-results-1", path="./rdn-results")
# Out:
# Successfully upload file ./rdn-results to OBS mipt-course/tendai/rdn-results-1
